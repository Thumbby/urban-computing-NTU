# %%
# import needed package
import random
from load_data import *
from visualize import *
import numpy as np
import os
import json

# %matplotlib inline

# %%
def extract_wifi_rssi(wifi_data):
    wifi_rssi = {}
    for position_key in wifi_data:
        wifi_ds = wifi_data[position_key]['wifi']
        for wifi_d in wifi_ds:
            bssid = wifi_d[1]
            rssi = int(wifi_d[2])

            if bssid in wifi_rssi:
                position_rssi = wifi_rssi[bssid]
                if position_key in position_rssi:
                    rssi = position_rssi[position_key][0]
                    wifi_count = position_rssi[position_key][1]
                    position_rssi[position_key][0] = (rssi * (wifi_count + 1)) / (wifi_count + 1)
                    position_rssi[position_key][1] += 1
                else:
                    position_rssi[position_key] = [rssi, 1]
            else:
                position_rssi = {position_key: [rssi, 1]}

            wifi_rssi[bssid] = position_rssi

    return wifi_rssi

# %%
def visualize_heatmap(position, value, floor_plan_file, width, height, colorbar_title, save_path, save_name, title=None,
                      show=False):
    # configure
    fig, ax = plt.subplots()
    font_dict = {'fontsize': 14,
                 'fontweight': 8.2,
                 'verticalalignment': 'baseline',
                 'horizontalalignment': 'left'}
    plt.title(title, fontdict=font_dict, loc='left')

    # add floor plan
    img = plt.imread(floor_plan_file)
    ax.imshow(img, extent=(0, width, 0, height))

    ax.xaxis.set_major_locator(ticker.MultipleLocator(20))
    ax.xaxis.set_minor_locator(ticker.MultipleLocator(5))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(20))
    ax.yaxis.set_minor_locator(ticker.MultipleLocator(5))

    plt.scatter(
        x=position[:, 0],
        y=position[:, 1],
        c=value,
        cmap='gist_rainbow_r',
        s=10
    )
    plt.colorbar(label=colorbar_title, orientation='horizontal')

    plt.savefig(os.path.join(save_path, save_name), format='PNG', dpi=160)

    if show:
        plt.show()

# %%
def vis_wifi(site, floor, select_random=True):
    print('Processing wifi rssi on floor', floor, 'in', site)
    file_path = os.path.join('../data/', site, floor)
    floor_info_path = os.path.join(file_path, 'floor_info.json')
    floor_image_path = os.path.join(file_path, 'floor_image.png')

    with open(floor_info_path) as floor_info_file:
        map_info = json.load(floor_info_file)['map_info']

    map_height = map_info['height']
    map_width = map_info['width']

    path_data_files = os.path.join(file_path, 'path_data_files')
    wifi_data = combine_data_with_position(path_data_files)
    wifi_rssi = extract_wifi_rssi(wifi_data)
    if select_random:
        target_wifi = random.choice(list(wifi_rssi.keys()))
        print("The chosen wifi ap bssid is:", target_wifi)
    else:
        print('There are 10 example wifi ap bssid:')
        for _ in range(0, 10):
            print(random.choice(list(wifi_rssi.keys())))
        target_wifi = input(f"Please input target wifi ap bssid:\n")
    position = np.array(list(wifi_rssi[target_wifi].keys()))
    values = np.array(list(wifi_rssi[target_wifi].values()))[:, 0]
    visualize_heatmap(position, values, floor_image_path, map_width, map_height, colorbar_title='wifi_rssi',
                      save_path='../out/wifi_rssi', save_name=f'{target_wifi.replace(":", "-")}.png',
                      title=f'Wifi: {target_wifi} RSSI', show=True)

# %%
vis_wifi('site1', 'F1', True)
# Out:
# Processing wifi rssi on floor F1 in site1
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7aac5b77e0006b1732b.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7abc5b77e0006b1732d.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7b29191710006b5705b.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7b7c5b77e0006b1732f.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7ba9191710006b5705d.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7bdc5b77e0006b17331.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7bf9191710006b5705f.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c1c5b77e0006b17333.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c29191710006b57061.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c4c5b77e0006b17335.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c59191710006b57063.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c59191710006b57065.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c5c5b77e0006b17337.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c6c5b77e0006b17339.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c79191710006b57067.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c8c5b77e0006b1733b.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7c99191710006b57069.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7cac5b77e0006b1733d.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7cb9191710006b5706b.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7ccc5b77e0006b1733f.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7ce9191710006b5706d.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7cf9191710006b5706f.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7cfc5b77e0006b17341.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7d1c5b77e0006b17343.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7d29191710006b57071.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7d4c5b77e0006b17345.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7d69191710006b57073.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7d7c5b77e0006b17347.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7d89191710006b57075.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9e7dac5b77e0006b17349.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef829191710006b5707a.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef84c5b77e0006b17355.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef859191710006b5707c.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef87c5b77e0006b17357.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef8a9191710006b5707e.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef8dc5b77e0006b17359.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef8f9191710006b57080.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef919191710006b57082.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef91c5b77e0006b1735b.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef94c5b77e0006b1735d.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef959191710006b57084.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef95c5b77e0006b1735f.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef979191710006b57086.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef999191710006b57088.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9ef99c5b77e0006b17361.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa29191710006b5708a.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa2c5b77e0006b17363.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa5c5b77e0006b17365.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa69191710006b5708c.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa79191710006b5708e.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa7c5b77e0006b17367.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa8c5b77e0006b17369.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa99191710006b57090.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efa99191710006b57092.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efabc5b77e0006b1736b.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efac9191710006b57094.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efacc5b77e0006b1736d.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efad9191710006b57096.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efafc5b77e0006b1736f.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9efb0c5b77e0006b17371.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd2cc5b77e0006b173ba.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd30c5b77e0006b173bc.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd37c5b77e0006b173be.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd3a9191710006b570d2.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd3b9191710006b570d4.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd3bc5b77e0006b173c0.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd3dc5b77e0006b173c2.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd3e9191710006b570d6.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd40c5b77e0006b173c4.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd419191710006b570d8.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd43c5b77e0006b173c6.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd469191710006b570da.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd47c5b77e0006b173c8.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd489191710006b570dc.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd48c5b77e0006b173ca.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd499191710006b570de.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd49c5b77e0006b173cc.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd4c9191710006b570e0.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd4ec5b77e0006b173ce.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd4f9191710006b570e2.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd4fc5b77e0006b173d0.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd519191710006b570e4.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd53c5b77e0006b173d2.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd549191710006b570e6.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd57c5b77e0006b173d4.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd599191710006b570e8.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd5ac5b77e0006b173d6.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd5b9191710006b570ea.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd5dc5b77e0006b173d8.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd5e9191710006b570ec.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd5ec5b77e0006b173da.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd5f9191710006b570ee.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd60c5b77e0006b173dc.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd619191710006b570f0.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd61c5b77e0006b173de.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd629191710006b570f2.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd63c5b77e0006b173e0.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd649191710006b570f4.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd65c5b77e0006b173e2.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd669191710006b570f6.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dd9fd67c5b77e0006b173e4.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda0214c5b77e0006b17406.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda0216c5b77e0006b17408.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda02179191710006b5710e.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda02189191710006b57110.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda021ac5b77e0006b1740a.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda021c9191710006b57112.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda021dc5b77e0006b1740c.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda021e9191710006b57114.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda021fc5b77e0006b1740e.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda02209191710006b57116.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda0221c5b77e0006b17410.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda02239191710006b57118.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5dda0225c5b77e0006b17412.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5ddb9632c5b77e0006b179b1.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5ddb963a9191710006b5765c.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5ddb96f29191710006b57667.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5ddb96f39191710006b57669.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5ddb979ec5b77e0006b179b7.txt
# Processing file: E:\course\urban_computing\assignment\project_1\data\site1\F1\path_data_files\5ddb97a19191710006b57674.txt
# The chosen wifi ap bssid is: a8:0c:ca:8d:9f:74
